# %%
# %reset -f

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
import scipy
from scipy.stats import skewnorm

# %% [markdown]
# ### Normal Distribution

# %%
# Creating two normally distributed arrays for Target and Control Groups
tg_size = 100
cg_size = 100

np.random.seed(7)

tg = np.random.normal(loc=37, scale=3, size=tg_size)
cg = np.random.normal(loc=36.4, scale=3, size=cg_size)

# %%
# Calculating mean values for Target and Control Groups
tg_mean = np.mean(tg)
cg_mean = np.mean(cg)

# Creating Distributions plot for our arrays
fig, ax = plt.subplots(figsize=(10,6))

sns.distplot(tg, bins=10, ax=ax, label='', color='b')
# sns.distplot(cg, bins=10, ax=ax, label='CG', color='g')

ax.axvline(linewidth=2, linestyle='--', color='b', x=tg_mean)
# ax.axvline(linewidth=2, linestyle='--', color='g', x=cg_mean)

plt.title('Normal distribution')
plt.legend()

# Adding annotations
# ax.annotate(str(round(tg_mean,0)), xy=(tg_mean, 0), xytext=(tg_mean, 0), arrowprops=dict(facecolor='b', shrink=0.05),)
# ax.annotate(str(round(cg_mean,0)), xy=(cg_mean, 0), xytext=(cg_mean, 0), arrowprops=dict(facecolor='g', shrink=0.05),)

# Saving plot
fig.savefig('distplot_normal.png')

plt.show()
# Out:
# C:\Users\a_abdraimov\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# No handles with labels found to put in legend.

# %% [markdown]
# #### T-test

# %%
t_test = scipy.stats.ttest_ind(tg, cg)

# %%
t_test
# Out:
# Ttest_indResult(statistic=1.9910813548709969, pvalue=0.047846896240267577)

# %%
'''
thus ttest_ind calculates two-sided test and we have statistics > 0 
then we have to divide p-value by 2 in order to get one-sided p-value

'''
p_value = t_test.pvalue/2

# %%
p_value*100
# Out:
# 2.3923448120133788

# %% [markdown]
# ### Skewed Distribution

# %%
tg_size = 100
cg_size = 100

tg_a = 20
cg_a = 10


scipy.random.seed(7)

tg = skewnorm.rvs(tg_a, size=tg_size)+30
cg = skewnorm.rvs(cg_a, size=cg_size)+30

tg_mean = np.mean(tg)
cg_mean = np.mean(cg)

fig, ax = plt.subplots(figsize=(10,6))

sns.distplot(tg, bins=10, ax=ax, label='', color='b')
# sns.distplot(cg, bins=10, ax=ax, label='CG', color='g')

ax.axvline(linewidth=2, linestyle='--', color='b', x=tg_mean)
# ax.axvline(linewidth=2, linestyle='--', color='g', x=cg_mean)

plt.legend()
plt.title('Skewed, left')

# Saving plot
fig.savefig('distplot_skewed_1.png')
plt.show()
# Out:
# C:\Users\a_abdraimov\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# No handles with labels found to put in legend.

# %%
tg_size = 100
cg_size = 100

tg_a = -20
cg_a = -10

scipy.random.seed(7)

tg = skewnorm.rvs(tg_a, size=tg_size)+30
cg = skewnorm.rvs(cg_a, size=cg_size)+30

tg_mean = np.mean(tg)
cg_mean = np.mean(cg)

fig, ax = plt.subplots(figsize=(10,6))

sns.distplot(tg, bins=10, ax=ax, label='', color='b')
# sns.distplot(cg, bins=10, ax=ax, label='CG', color='g')

ax.axvline(linewidth=2, linestyle='--', color='b', x=tg_mean)
# ax.axvline(linewidth=2, linestyle='--', color='g', x=cg_mean)

plt.legend()
plt.title('Skewed, right')

# Saving plot
fig.savefig('distplot_skewed_2.png')

plt.show()
# Out:
# C:\Users\a_abdraimov\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# No handles with labels found to put in legend.
